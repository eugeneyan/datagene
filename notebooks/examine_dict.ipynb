# %%
import cPickle as pickle

# %%
with open('../data/model/categorization_dicts.pickle', 'rb') as handle:
    df = pickle.load(handle)

# %%
df[0]
# Out:
# defaultdict(None,
#             {'patti_labelle_women': defaultdict(None,
#                          {1634: 0.30207154861242735}),
#              'stockings_anti-embolism': defaultdict(None,
#                          {3587: 0.4315307837320391, 3597: 0.1150748756618771}),
#              'sketching_project_set': defaultdict(None,
#                          {8587: 0.8055241296331397}),
#              'hjc_is-17_genesis': defaultdict(None, {671: 0.3452246269856313}),
#              'cufflinks_small': defaultdict(None, {2279: 0.24165723888994192}),
#              'lubrication_g160': defaultdict(None,
#                          {1400: 0.48331447777988384}),
#              'seagate_stm900603otabe1-rk_2.5-inch': defaultdict(None,
#                          {3082: 0.3452246269856313}),
#              'traditional_german': defaultdict(None,
#                          {2252: 0.40276206481656984}),
#              'hooker_16623hkr_dual': defaultdict(None,
# ...
